# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset('planets')
data.head(10)
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009
# 5  Radial Velocity       1         185.840   4.80     76.39  2008
# 6  Radial Velocity       1        1773.400   4.64     18.15  2002
# 7  Radial Velocity       1         798.500    NaN     21.41  1996
# 8  Radial Velocity       1         993.300  10.30     73.10  2008
# 9  Radial Velocity       2         452.800   1.99     74.79  2010

# %%
sns.barplot(x='mass', y='orbital_period', data=data.head(10))
# Out:
# <AxesSubplot:xlabel='mass', ylabel='orbital_period'>

# %%
sns.relplot(x='mass', y='orbital_period', data=data.head(30))

# %%
sns.lmplot(x='mass', y='orbital_period', data=data.head(30))

# %% [markdown]
# # Summary
# no relation between the mass and the speed
